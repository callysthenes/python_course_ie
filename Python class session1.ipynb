# %% [markdown]
# # ***In Colab and Jupyter we may also write text that is not code***

# %%
#https://docs.python.org/3.7/tutorial/

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
print ("hello world!")
# Out:
# hello world!

# %%
help
# Out:
# Type help() for interactive help, or help(object) for help about object.

# %%
help()
# Out:
# Welcome to Python 3.7's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the Internet at https://docs.python.org/3.7/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".
#
# help> print
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
# ...

# %%
g=2+2
print (g)
# Out:
# 4

# %%
print ("My name is Pedro\n I am 32, Spanish-Ecuadorian \n I love adventure sports)
print ("I am 32, Spanish-Ecuadorian, and love adventure sports")
# Out:
#   File "<ipython-input-1-ea731dd6af0d>", line 1
#     print ("My name is Pedro\n I am 32, Spanish-Ecuadorian \n I love adventure sports)
#                                                                                       ^
# SyntaxError: EOL while scanning string literal

# %%
print ("My name is Pedro\n I am 32, Spanish-Ecuadorian \ I love adventure sports")
# Out:
# My name is Pedro
#  I am 32, Spanish-Ecuadorian \ I love adventure sports

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
example = pd.read_csv(https://ec.europa.eu/info/sites/default/files/market-prices-vegetal-products_en_7.csv)
# Out:
#   File "<ipython-input-48-1294e45253d6>", line 1
#     example = pd.read_csv(https://ec.europa.eu/info/sites/default/files/market-prices-vegetal-products_en_7.csv)
#                                ^
# SyntaxError: invalid syntax

# %%
print("    *")
print("   * *")
print("  *   *")
print(" *     *")
print("***   ***")
print("  *   *")
print("  *   *")
print("  *****")
# Out:
#     *
#    * *
#   *   *
#  *     *
# ***   ***
#   *   *
#   *   *
#   *****

# %%
print(2)
# Out:
# 2

# %%
3*9
# Out:
# 27

# %%
a=3
print (a)
type (a)
# Out:
# 3
# int

# %%
name = "Pedro"
print (name)
type (name)
# Out:
# Pedro
# str

# %%
b= -8.6
type (b)
# Out:
# float

# %%
c = True
type (c)
# Out:
# bool

# %%
2**3
# Out:
# 8

# %%
y=2+5*4
print(y)
# Out:
# 22

# %%
name = "Pedro"

# %%
22//4
# Out:
# 5

# %%
name2= "Lucia"

# %%
name = name2

# %%
name
# Out:
# 'Lucia'

# %%
j=7

# %%
h = name * j
print (h)
# Out:
# PedroPedroPedroPedroPedroPedroPedro

# %%
5-6*3
# Out:
# -13

# %%
g = a+b
print (g)
type (g)
# Out:
# -5.6
# float

# %%
kilometers = 626
miles = 8000

miles_to_kilometers = 1.60
kilometers_to_miles = .62

print(miles, "miles is", miles*miles_to_kilometers , "kilometers")
print(kilometers, "kilometers is", kilometers*kilometers_to_miles, "miles")
# Out:
# 8000 miles is 12800.0 kilometers
# 626 kilometers is 388.12 miles

# %%
days = int(input("Enter the number of days you want to convert into seconds: "))

day_to_seconds = 24*3600

print(days, "days is equivalent to", days*day_to_seconds, "seconds")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-90-cbaba0019b51> in <module>
# ----> 1 days = int(input("Enter the number of days you want to convert into seconds: "))
#       2
#       3 day_to_seconds = 24*3600
#       4
#       5 print(days, "days is equivalent to", days*day_to_seconds, "seconds")
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %% [markdown]
# Lists

# %%
cars = ["Ford Fiesta", "Honda Accord", "Saab 93", "Toyota MR2", "Lexus IS200", "Audi A6", "Ford Transit", "Land Rover Defender", "Galloper Exceed", "Toyota Corolla", "BMW M3", "Mercedes C-Class"]

# %%
len (cars)
# Out:
# 12

# %%
cars
# Out:
# ['Mercedes C-Class',
#  'BMW M3',
#  'Toyota Corolla',
#  'Galloper Exceed',
#  'Land Rover Defender',
#  'Ford Transit',
#  'Audi A6',
#  'Lexus IS200',
#  'Toyota MR2',
#  'Saab 93',
#  'Honda Accord',
#  'Ford Fiesta']

# %%
firstcar = f"My first car was a {cars[0].title()}."

# %%
firstcar = "My first car was a {cars[0].title()}."

# %%
print (firstcar)
# Out:
# My first car was a {cars[0].title()}.

# %%
cars.reverse()

# %%
print (cars)
# Out:
# ['Audi A6', 'BMW M3', 'Ford Fiesta', 'Ford Transit', 'Galloper Exceed', 'Honda Accord', 'Land Rover Defender', 'Lexus IS200', 'Mercedes C-Class', 'Saab 93', 'Toyota Corolla', 'Toyota MR2']

# %%
cars.sort()

# %%
cars [3]
# Out:
# 'Galloper Exceed'

# %%
cars [3] = "Mitsubishi Montero"

# %%
cars
# Out:
# ['Audi A6',
#  'BMW M3',
#  'Ford Fiesta',
#  'Mitsubishi Montero',
#  'Galloper Exceed',
#  'Honda Accord',
#  'Land Rover Defender',
#  'Lexus IS200',
#  'Mercedes C-Class',
#  'Saab 93',
#  'Toyota Corolla',
#  'Toyota MR2']

# %%
cars2 = ["Porsche 911"]

# %%
cars_consolidated = cars+cars2

# %%
cars_consolidated
# Out:
# ['Audi A6',
#  'BMW M3',
#  'Ford Fiesta',
#  'Mitsubishi Montero',
#  'Galloper Exceed',
#  'Honda Accord',
#  'Land Rover Defender',
#  'Lexus IS200',
#  'Mercedes C-Class',
#  'Saab 93',
#  'Toyota Corolla',
#  'Toyota MR2',
#  'Porsche 911',
#  'Renault Clio']

# %%
cars_consolidated.append("Renault Clio")

# %%
input_example
# Out:
# '2'

# %%
type(input_example)
# Out:
# str

# %%
input_example = input("Please enter a number: ")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-bb54d3101dfe> in <module>
# ----> 1 input_example = input("Please enter a number: ")
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# ...

# %%
type(input_example)
